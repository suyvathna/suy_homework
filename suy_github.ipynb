# %% [markdown]
# <a href="https://colab.research.google.com/github/suyvathna/suy_homework/blob/main/suy_github.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. This is answer related to GitHub: (10 points)

# %%
# i tried to add this notebook into the github repo as well but it fails because it warns me that there's token found in this notebook.
# i checked and found that we can use google collab secret to hide the key and must be retried by the following code:
from google.colab import userdata
import os
# token from my giithub
# create this token from Profile > Settings > Developer Settings > Personal access token > Token (classic) and paste it below
token = userdata.get('github_token')

# git configuration
# !git config --global user.email "vathna_suy@yahoo.com"
# !git config --global user.name "Suy Vathna"

username = "suyvathna"
repo = "suy_homework"

# %%
# clone the repo
# !git clone https://{token}@github.com/{username}/{repo}
# Out:
# Cloning into 'suy_homework'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (5/5), done.
# Receiving objects: 100% (6/6), done.
# remote: Total 6 (delta 0), reused 3 (delta 0), pack-reused 0 (from 0)

# %%
# %pwd
# Out:
# '/content'

# %%
# %cd suy_homework
# Out:
# /content/suy_homework

# %%
# %pwd
# Out:
# '/content/suy_homework'

# %%
# create a simple text file to test
# !touch testfile.txt   # this create a blank file with nothing in it
# to add some text, we use command !echo " " > filename.txt. Using the > will append the new line
# but if we want to erase the existing and add completely new lines use double >>
# !echo "this is the first line of my text file in my file for homework!" > testfile.txt

# !git add testfile.txt   # this will pack the file for upload into repo
# !git commit -m "i add a txt file"   # this is my commit message
# Out:
# [main 1b09a10] i add a txt file
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %%
# push the file to repo
# !git push
# Out:
# Enumerating objects: 5, done.
# Counting objects: 100% (5/5), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 349 bytes | 349.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/suyvathna/suy_homework
#    ea8f772..1b09a10  main -> main
